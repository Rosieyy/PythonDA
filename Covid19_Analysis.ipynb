# %% [markdown]
# # Covid19_trendAnalysis

# %%
#owid-covid-data.csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('C:\\Users\\leero\\Downloads\\owid-covid-data.csv')

# %%
df.head(8)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# ...

# %%
df.drop(['hosp_patients_per_million','weekly_icu_admissions'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.126                  0.126
# 1                    0.126                  0.000
# 2                    0.126                  0.000
# 3                    0.126                  0.000
# 4                    0.126                  0.000
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  ...  \
# 0                                NaN                     NaN  ...
# 1                                NaN                     NaN  ...
# ...

# %%
countries = df['location'].unique()
len(countries)
# Out:
# 238

# %% [markdown]
# ![image.png](attachment:ab8b19f4-f316-4f21-953b-2af3ae026b87.png)
